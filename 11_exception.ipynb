# %% [markdown]
# 자주 발생하는 예외 예

# %%
#FileNotFoundError
f = open('non.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 #[i]
# ----> 2 f = open('non.txt','r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'non.txt'

# %%
# ZeroDivision
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # ZeroDiv
# ----> 2 4/0
#
# ZeroDivisionError: division by zero

# %%
a = [1,2,3]
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = [1,2,3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# ## 1. 예외 처리 기법

# %% [markdown]
# try-except 구문

# %%
try:
    4/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print(4/3)
except ZeroDivisionError as e:
    print(e)
# Out:
# 1.3333333333333333

# %% [markdown]
# try-finally 문

# %%
try:
    f=open('none.txt','r')
except FileNotFoundError as e:
    print(e)
finally:
    f.
# Out:
#   Cell In[7], line 6
#     f.
#       ^
# SyntaxError: invalid syntax

# %%
try:
    f = open('foo.txt','w')
    #예외발생하면 이후에 실행문은 실행 안됨!!
    f.close()
finally:
    f.close()

# %% [markdown]
# 여러개 예외 처리

# %%
try:
    a=[1,2]
    print(a[3])
    4/0
except ZeroDivisionError:
        print('0으로 나눌 수 없습니다.')
except IndexError:
        print('인덱싱할 수 없습니다.')
# Out:
# 인덱싱할 수 없습니다.

# %%
try:
    4/0
    a=[1,2]
    print(a[3])
except ZeroDivisionError:
        print('0으로 나눌 수 없습니다.')
except IndexError:
        print('인덱싱할 수 없습니다.')
# Out:
# 0으로 나눌 수 없습니다.

# %%
try:
    4/0
    a = [1,2]
    print(a[3])
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a = [1,2]
    4/0
    print(a[3])
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a = [1,2]
    a[3]
    4/0
except Exception as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# try-else문

# %%
try:
    age = int(input('나이를 입력하세요:'))
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년 - 출입금지')
    else:
        print('성인 - 환영합니다.')
# Out:
# 미성년 - 출입금지

# %% [markdown]
# ## 2.예외 회피하기

# %%
try:
    f = open('none.txt','r')
except Exception:
    pass

# %% [markdown]
# ## 3. 예외 발생시키기

# %%
class Bird:
    def fly(self):
        raise NotImpIementedError

# %%
class Eagle(Bird):
    pass

eagle = Eagle()
eagle.fly()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       1 class Eagle(Bird):
#       2     pass
#       3
#       4 eagle = Eagle()
# ----> 5 eagle.fly()
#
# Cell In[25], line 3, in Bird.fly(self)
#       2     def fly(self):
# ----> 3         raise NotImpIementedError
#
# NameError: name 'NotImpIementedError' is not defined

# %%
class Eagle(Bird):
    def fly(self): #메서드 오버라이딩
        print('very fast')

eagle = Eagle
eagle.fly
# Out:
# <function __main__.Eagle.fly(self)>

# %% [markdown]
# ## 4.예외 만들기

# %%
class MyError(Exception):
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError() # 강제로 내가 만든  예외 발생
    print(nick)

# %%
say_nick('천사')
# Out:
# 천사

# %%
say_nick('바보')
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 say_nick('바보')
#
# Cell In[30], line 3, in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError() # 강제로 내가 만든  예외 발생
#       4     print(nick)
#
# MyError:

# %%
try:
    say_nick('천사')
    say_nick('바보')
except MyError:
    print('허용되지 않은 별명입니다.')
# Out:
# 천사
# 허용되지 않은 별명입니다.

# %%
try:
    say_nick('천사')
    say_nick('바보')
except MyError as e:
    print(e)
# Out:
# 천사

# %%
class MyError(Exception):
    def __str__(self):
        return "허용되지 않은 별명 입니다."

# %%
try:
    say_nick('천사')
    say_nick('바보')
except MyError as e:
    print(e)
# Out:
# 천사
# 허용되지 않은 별명 입니다.

# %%
say_nick('바보')
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 say_nick('바보')
#
# Cell In[30], line 3, in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError() # 강제로 내가 만든  예외 발생
#       4     print(nick)
#
# MyError: 허용되지 않은 별명 입니다.
