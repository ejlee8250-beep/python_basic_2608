# %% [markdown]
# ## 1. 숫자를 어떻게 사용할까요?

# %%
a=123

# %%
a
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
a=-178

# %%
a
# Out:
# -178

# %%
a=0
a
# Out:
# 0

# %%
a=1.2
a
# Out:
# 1.2

# %%
a=-3.45
a
# Out:
# -3.45

# %%
a=4.24E10
a
# Out:
# 42400000000.0

# %%
a=4.24E-10
a
# Out:
# 4.24e-10

# %%
a=0o177
a
# Out:
# 127

# %%
a=0x8ff
a
# Out:
# 2303

# %%
b=0xABC
b
# Out:
# 2748

# %% [markdown]
# ## 2.숫자를 활용하기 위한 연산자
# ## 사직연산

# %%
a=3
b=4

# %%
a+b
# Out:
# 8

# %% [markdown]
# ## 제곱(**)연산자

# %%
a**b
# Out:
# 256

# %% [markdown]
# ## 나머지(&) 연산자

# %%
7%3
# Out:
# 1

# %% [markdown]
# ## 몫(//)연산자

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1
